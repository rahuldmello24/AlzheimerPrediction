# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
import seaborn as sns

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv("data/alzheimers_prediction_dataset.csv")

# %%
df.head()
# Out:
#         Country  Age  Gender  Education Level   BMI Physical Activity Level  \
# 0         Spain   90    Male                1  33.0                  Medium
# 1     Argentina   72    Male                7  29.9                  Medium
# 2  South Africa   86  Female               19  22.9                    High
# 3         China   53    Male               17  31.2                     Low
# 4        Sweden   58  Female                3  30.0                    High
#
#   Smoking Status Alcohol Consumption Diabetes Hypertension  ...  \
# 0          Never        Occasionally       No           No  ...
# 1         Former               Never       No           No  ...
# 2        Current        Occasionally       No          Yes  ...
# 3          Never           Regularly      Yes           No  ...
# 4         Former               Never      Yes           No  ...
#
#   Dietary Habits Air Pollution Exposure  Employment Status Marital Status  \
# 0        Healthy                   High            Retired         Single
# 1        Healthy                 Medium         Unemployed        Widowed
# 2        Average                 Medium           Employed         Single
# 3        Healthy                 Medium            Retired         Single
# 4      Unhealthy                   High           Employed        Married
#
#   Genetic Risk Factor (APOE-ε4 allele) Social Engagement Level Income Level  \
# 0                                   No                     Low       Medium
# 1                                   No                    High          Low
# 2                                   No                     Low       Medium
# 3                                   No                    High       Medium
# 4                                   No                     Low       Medium
#
#   Stress Levels Urban vs Rural Living Alzheimer’s Diagnosis
# 0          High                 Urban                    No
# 1          High                 Urban                    No
# 2          High                 Rural                    No
# 3           Low                 Rural                    No
# 4          High                 Rural                    No
#
# [5 rows x 25 columns]

# %%
size = df.shape[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74283 entries, 0 to 74282
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               74283 non-null  object
#  1   Age                                   74283 non-null  int64
#  2   Gender                                74283 non-null  object
#  3   Education Level                       74283 non-null  int64
#  4   BMI                                   74283 non-null  float64
#  5   Physical Activity Level               74283 non-null  object
#  6   Smoking Status                        74283 non-null  object
#  7   Alcohol Consumption                   74283 non-null  object
#  8   Diabetes                              74283 non-null  object
#  9   Hypertension                          74283 non-null  object
#  10  Cholesterol Level                     74283 non-null  object
#  11  Family History of Alzheimer’s         74283 non-null  object
#  12  Cognitive Test Score                  74283 non-null  int64
#  13  Depression Level                      74283 non-null  object
#  14  Sleep Quality                         74283 non-null  object
#  15  Dietary Habits                        74283 non-null  object
#  16  Air Pollution Exposure                74283 non-null  object
#  17  Employment Status                     74283 non-null  object
#  18  Marital Status                        74283 non-null  object
#  19  Genetic Risk Factor (APOE-ε4 allele)  74283 non-null  object
#  20  Social Engagement Level               74283 non-null  object
#  21  Income Level                          74283 non-null  object
#  22  Stress Levels                         74283 non-null  object
#  23  Urban vs Rural Living                 74283 non-null  object
#  24  Alzheimer’s Diagnosis                 74283 non-null  object
# dtypes: float64(1), int64(3), object(21)
# memory usage: 14.2+ MB

# %% [markdown]
# No columns have any null values
#
# Check distribution of target label

# %%
value_counts = df["Alzheimer’s Diagnosis"].value_counts()
label, count = list(value_counts.index), value_counts.values
plt.bar(label, count, color="green")
plt.xlabel('Alzheimer’s Diagnosis Label')
plt.ylabel('Frequency')
plt.title('Class Label Distribution in DataFrame')
plt.xticks(label)  # Set x-ticks to be the class labels
plt.show()

# %% [markdown]
# Need to fix balance of data

# %%
# run this cell if you are using scikit-learn version 1.3.X
#!pip uninstall scikit-learn --yes
#!pip install scikit-learn==1.2.2
# restart kernal after

# %%
from imblearn.over_sampling import RandomOverSampler # over sample to fix data
X = df.drop("Alzheimer’s Diagnosis", axis=1) 
y = df["Alzheimer’s Diagnosis"]
ros = RandomOverSampler(random_state=42)
X_sample, y_sample = ros.fit_resample(X, y)

# %%
print(y_sample)
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 87135    Yes
# 87136    Yes
# 87137    Yes
# 87138    Yes
# 87139    Yes
# Name: Alzheimer’s Diagnosis, Length: 87140, dtype: object

# %%
# Stitch df back together with sample values
df= pd.concat((X_sample, y_sample), axis=1)
df.head()
# Out:
#         Country  Age  Gender  Education Level   BMI Physical Activity Level  \
# 0         Spain   90    Male                1  33.0                  Medium
# 1     Argentina   72    Male                7  29.9                  Medium
# 2  South Africa   86  Female               19  22.9                    High
# 3         China   53    Male               17  31.2                     Low
# 4        Sweden   58  Female                3  30.0                    High
#
#   Smoking Status Alcohol Consumption Diabetes Hypertension  ...  \
# 0          Never        Occasionally       No           No  ...
# 1         Former               Never       No           No  ...
# 2        Current        Occasionally       No          Yes  ...
# 3          Never           Regularly      Yes           No  ...
# 4         Former               Never      Yes           No  ...
#
#   Dietary Habits Air Pollution Exposure  Employment Status Marital Status  \
# 0        Healthy                   High            Retired         Single
# 1        Healthy                 Medium         Unemployed        Widowed
# 2        Average                 Medium           Employed         Single
# 3        Healthy                 Medium            Retired         Single
# 4      Unhealthy                   High           Employed        Married
#
#   Genetic Risk Factor (APOE-ε4 allele) Social Engagement Level Income Level  \
# 0                                   No                     Low       Medium
# 1                                   No                    High          Low
# 2                                   No                     Low       Medium
# 3                                   No                    High       Medium
# 4                                   No                     Low       Medium
#
#   Stress Levels Urban vs Rural Living Alzheimer’s Diagnosis
# 0          High                 Urban                    No
# 1          High                 Urban                    No
# 2          High                 Rural                    No
# 3           Low                 Rural                    No
# 4          High                 Rural                    No
#
# [5 rows x 25 columns]

# %%
value_counts = df["Alzheimer’s Diagnosis"].value_counts()
label, count = list(value_counts.index), value_counts.values
plt.bar(label, count, color="green")
plt.xlabel('Alzheimer’s Diagnosis Label')
plt.ylabel('Frequency')
plt.title('Class Label Distribution in DataFrame')
plt.xticks(label)  # Set x-ticks to be the class labels
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87140 entries, 0 to 87139
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               87140 non-null  object
#  1   Age                                   87140 non-null  int64
#  2   Gender                                87140 non-null  object
#  3   Education Level                       87140 non-null  int64
#  4   BMI                                   87140 non-null  float64
#  5   Physical Activity Level               87140 non-null  object
#  6   Smoking Status                        87140 non-null  object
#  7   Alcohol Consumption                   87140 non-null  object
#  8   Diabetes                              87140 non-null  object
#  9   Hypertension                          87140 non-null  object
#  10  Cholesterol Level                     87140 non-null  object
#  11  Family History of Alzheimer’s         87140 non-null  object
#  12  Cognitive Test Score                  87140 non-null  int64
#  13  Depression Level                      87140 non-null  object
#  14  Sleep Quality                         87140 non-null  object
#  15  Dietary Habits                        87140 non-null  object
#  16  Air Pollution Exposure                87140 non-null  object
#  17  Employment Status                     87140 non-null  object
#  18  Marital Status                        87140 non-null  object
#  19  Genetic Risk Factor (APOE-ε4 allele)  87140 non-null  object
#  20  Social Engagement Level               87140 non-null  object
#  21  Income Level                          87140 non-null  object
#  22  Stress Levels                         87140 non-null  object
#  23  Urban vs Rural Living                 87140 non-null  object
#  24  Alzheimer’s Diagnosis                 87140 non-null  object
# dtypes: float64(1), int64(3), object(21)
# memory usage: 16.6+ MB

# %%
df.describe()
# Out:
#                 Age  Education Level           BMI  Cognitive Test Score
# count  87140.000000     87140.000000  87140.000000          87140.000000
# mean      72.903259         9.479722     26.776125             64.643665
# std       12.933662         5.753242      4.767219             20.145815
# min       50.000000         0.000000     18.500000             30.000000
# 25%       62.000000         4.000000     22.700000             47.000000
# 50%       74.000000         9.000000     26.800000             65.000000
# 75%       84.000000        14.000000     30.900000             82.000000
# max       94.000000        19.000000     35.000000             99.000000

# %% [markdown]
# Some range in values, will use standard scalar to fix this because there is no reason to not use another (not a big range, not highly skewed)

# %%
scaler = StandardScaler()
numerical_cols = ["Age", "Education Level", "BMI", "Cognitive Test Score"]
df_numerical = df[numerical_cols]
scaled = scaler.fit_transform(df_numerical)
df[numerical_cols] = scaled
df.describe()
# Out:
#                 Age  Education Level           BMI  Cognitive Test Score
# count  8.714000e+04     8.714000e+04  8.714000e+04          8.714000e+04
# mean   3.026778e-16     8.875669e-17 -1.009592e-15          2.915883e-16
# std    1.000006e+00     1.000006e+00  1.000006e+00          1.000006e+00
# min   -1.770836e+00    -1.647728e+00 -1.736059e+00         -1.719656e+00
# 25%   -8.430189e-01    -9.524636e-01 -8.550368e-01         -8.758031e-01
# 50%    8.479788e-02    -8.338342e-02  5.008268e-03          1.768788e-02
# 75%    8.579785e-01     7.856967e-01  8.650533e-01          8.615404e-01
# max    1.631159e+00     1.654777e+00  1.725098e+00          1.705393e+00

# %%
df.describe(include="object")
# Out:
#        Country  Gender Physical Activity Level Smoking Status  \
# count    87140   87140                   87140          87140
# unique      20       2                       3              3
# top     Brazil  Female                    High        Current
# freq      4573   43619                   29176          29212
#
#        Alcohol Consumption Diabetes Hypertension Cholesterol Level  \
# count                87140    87140        87140             87140
# unique                   3        2            2                 2
# top                  Never       No           No            Normal
# freq                 29087    69832        61185             61086
#
#        Family History of Alzheimer’s Depression Level  ... Dietary Habits  \
# count                          87140            87140  ...          87140
# unique                             2                3  ...              3
# top                               No           Medium  ...        Average
# freq                           59957            29164  ...          29162
#
#        Air Pollution Exposure Employment Status Marital Status  \
# count                   87140             87140          87140
# unique                      3                 3              3
# top                      High        Unemployed         Single
# freq                    29297             29080          29465
#
#        Genetic Risk Factor (APOE-ε4 allele) Social Engagement Level  \
# count                                 87140                   87140
# unique                                    2                       3
# top                                      No                  Medium
# freq                                  68571                   29171
#
#        Income Level Stress Levels Urban vs Rural Living Alzheimer’s Diagnosis
# count         87140         87140                 87140                 87140
# unique            3             3                     2                     2
# top            High        Medium                 Rural                    No
# freq          29124         29182                 43704                 43570
#
# [4 rows x 21 columns]

# %% [markdown]
# Country will get dropped because there are too many values to encode. This would lead to curse of dimensionality or the model creating an ordinal relationship between countries when one does not exist. Also, should not contribute to target variable.

# %%
df = df.drop(columns=["Country"])

# %%
df.describe(include="object")
# Out:
#         Gender Physical Activity Level Smoking Status Alcohol Consumption  \
# count    87140                   87140          87140               87140
# unique       2                       3              3                   3
# top     Female                    High        Current               Never
# freq     43619                   29176          29212               29087
#
#        Diabetes Hypertension Cholesterol Level Family History of Alzheimer’s  \
# count     87140        87140             87140                         87140
# unique        2            2                 2                             2
# top          No           No            Normal                            No
# freq      69832        61185             61086                         59957
#
#        Depression Level Sleep Quality Dietary Habits Air Pollution Exposure  \
# count             87140         87140          87140                  87140
# unique                3             3              3                      3
# top              Medium          Good        Average                   High
# freq              29164         29488          29162                  29297
#
#        Employment Status Marital Status Genetic Risk Factor (APOE-ε4 allele)  \
# count              87140          87140                                87140
# unique                 3              3                                    2
# top           Unemployed         Single                                   No
# freq               29080          29465                                68571
#
#        Social Engagement Level Income Level Stress Levels  \
# count                    87140        87140         87140
# unique                       3            3             3
# top                     Medium         High        Medium
# freq                     29171        29124         29182
#
#        Urban vs Rural Living Alzheimer’s Diagnosis
# count                  87140                 87140
# unique                     2                     2
# top                    Rural                    No
# freq                   43704                 43570

# %% [markdown]
# All columns with only 2 or 3 values. This means one-hot encoding should work for most. However, for columns like physical activity, cholesterol, Depression, Air pollution, the labels are along the lines of low, medium, and high. This means label encoding is suitable for these columns as there is an ordinal relationship between the values.

# %%
print("Unique values for:\nAlcohol Consumption: ", df["Alcohol Consumption"].unique()) # one-hot
print("Smoking Status: ", df["Smoking Status"].unique()) # one-hot
print("Depression Level: ", df["Depression Level"].unique()) # try label
print("Dietary Habits: ", df["Dietary Habits"].unique()) # one-hot
print("Employment Status: ", df["Employment Status"].unique()) # one-hot
print("Marital Status: ", df["Marital Status"].unique()) # one-hot
print("Social Engagement Level: ", df["Social Engagement Level"].unique()) # try label
# Out:
# Unique values for:
# Alcohol Consumption:  ['Occasionally' 'Never' 'Regularly']
# Smoking Status:  ['Never' 'Former' 'Current']
# Depression Level:  ['Low' 'High' 'Medium']
# Dietary Habits:  ['Healthy' 'Average' 'Unhealthy']
# Employment Status:  ['Retired' 'Unemployed' 'Employed']
# Marital Status:  ['Single' 'Widowed' 'Married']
# Social Engagement Level:  ['Low' 'High' 'Medium']

# %%
object_cols = df.select_dtypes("object").columns.tolist()
label_enc_cols = ["Physical Activity Level", "Depression Level", "Sleep Quality",  "Air Pollution Exposure",
                 "Social Engagement Level", "Income Level", "Stress Levels"] 
one_hot_cols = list(set(object_cols) - set(label_enc_cols))
# try doing label encoding to see if it is better than one-hot for all

# %%
df_ohe = pd.get_dummies(df, columns=object_cols, drop_first=True)
df_ohe.head() # one hot binary values
# Out:
#         Age  Education Level       BMI  Cognitive Test Score  Gender_Male  \
# 0  1.321887        -1.473912  1.305564              1.258648         True
# 1 -0.069838        -0.431015  0.655286              0.017688         True
# 2  1.012615         1.654777 -0.813083             -1.074357        False
# 3 -1.538881         1.307145  0.927983              0.811902         True
# 4 -1.152291        -1.126280  0.676263             -0.776526        False
#
#    Physical Activity Level_Low  Physical Activity Level_Medium  \
# 0                        False                            True
# 1                        False                            True
# 2                        False                           False
# 3                         True                           False
# 4                        False                           False
#
#    Smoking Status_Former  Smoking Status_Never  \
# 0                  False                  True
# 1                   True                 False
# 2                  False                 False
# 3                  False                  True
# 4                   True                 False
#
#    Alcohol Consumption_Occasionally  ...  Marital Status_Widowed  \
# 0                              True  ...                   False
# 1                             False  ...                    True
# 2                              True  ...                   False
# 3                             False  ...                   False
# 4                             False  ...                   False
#
#    Genetic Risk Factor (APOE-ε4 allele)_Yes  Social Engagement Level_Low  \
# 0                                     False                         True
# 1                                     False                        False
# 2                                     False                         True
# 3                                     False                        False
# 4                                     False                         True
#
#    Social Engagement Level_Medium  Income Level_Low  Income Level_Medium  \
# 0                           False             False                 True
# 1                           False              True                False
# 2                           False             False                 True
# 3                           False             False                 True
# 4                           False             False                 True
#
#    Stress Levels_Low  Stress Levels_Medium  Urban vs Rural Living_Urban  \
# 0              False                 False                         True
# 1              False                 False                         True
# 2              False                 False                        False
# 3               True                 False                        False
# 4              False                 False                        False
#
#    Alzheimer’s Diagnosis_Yes
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
#
# [5 rows x 36 columns]

# %%
df_ohe.info() # information of new data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87140 entries, 0 to 87139
# Data columns (total 36 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Age                                       87140 non-null  float64
#  1   Education Level                           87140 non-null  float64
#  2   BMI                                       87140 non-null  float64
#  3   Cognitive Test Score                      87140 non-null  float64
#  4   Gender_Male                               87140 non-null  bool
#  5   Physical Activity Level_Low               87140 non-null  bool
#  6   Physical Activity Level_Medium            87140 non-null  bool
#  7   Smoking Status_Former                     87140 non-null  bool
#  8   Smoking Status_Never                      87140 non-null  bool
#  9   Alcohol Consumption_Occasionally          87140 non-null  bool
#  10  Alcohol Consumption_Regularly             87140 non-null  bool
#  11  Diabetes_Yes                              87140 non-null  bool
#  12  Hypertension_Yes                          87140 non-null  bool
#  13  Cholesterol Level_Normal                  87140 non-null  bool
#  14  Family History of Alzheimer’s_Yes         87140 non-null  bool
#  15  Depression Level_Low                      87140 non-null  bool
#  16  Depression Level_Medium                   87140 non-null  bool
#  17  Sleep Quality_Good                        87140 non-null  bool
#  18  Sleep Quality_Poor                        87140 non-null  bool
#  19  Dietary Habits_Healthy                    87140 non-null  bool
#  20  Dietary Habits_Unhealthy                  87140 non-null  bool
#  21  Air Pollution Exposure_Low                87140 non-null  bool
#  22  Air Pollution Exposure_Medium             87140 non-null  bool
#  23  Employment Status_Retired                 87140 non-null  bool
#  24  Employment Status_Unemployed              87140 non-null  bool
#  25  Marital Status_Single                     87140 non-null  bool
#  26  Marital Status_Widowed                    87140 non-null  bool
#  27  Genetic Risk Factor (APOE-ε4 allele)_Yes  87140 non-null  bool
#  28  Social Engagement Level_Low               87140 non-null  bool
#  29  Social Engagement Level_Medium            87140 non-null  bool
#  30  Income Level_Low                          87140 non-null  bool
#  31  Income Level_Medium                       87140 non-null  bool
#  32  Stress Levels_Low                         87140 non-null  bool
#  33  Stress Levels_Medium                      87140 non-null  bool
#  34  Urban vs Rural Living_Urban               87140 non-null  bool
#  35  Alzheimer’s Diagnosis_Yes                 87140 non-null  bool
# dtypes: bool(32), float64(4)
# memory usage: 5.3 MB

# %%
ohe_corr = df_ohe.corr() # heat map of correlation
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(ohe_corr, ax=ax)
plt.title("Correlation between one hot encoded features")
plt.show()

# %%
df_label = df.copy() # new df for label encoding

# %%
le = LabelEncoder()
for col in label_enc_cols:
    df_label[col] = le.fit_transform(df[col])
df_label.head()
# Out:
#         Age  Gender  Education Level       BMI  Physical Activity Level  \
# 0  1.321887    Male        -1.473912  1.305564                        2
# 1 -0.069838    Male        -0.431015  0.655286                        2
# 2  1.012615  Female         1.654777 -0.813083                        0
# 3 -1.538881    Male         1.307145  0.927983                        1
# 4 -1.152291  Female        -1.126280  0.676263                        0
#
#   Smoking Status Alcohol Consumption Diabetes Hypertension Cholesterol Level  \
# 0          Never        Occasionally       No           No            Normal
# 1         Former               Never       No           No            Normal
# 2        Current        Occasionally       No          Yes            Normal
# 3          Never           Regularly      Yes           No            Normal
# 4         Former               Never      Yes           No            Normal
#
#    ... Dietary Habits  Air Pollution Exposure  Employment Status  \
# 0  ...        Healthy                       0            Retired
# 1  ...        Healthy                       2         Unemployed
# 2  ...        Average                       2           Employed
# 3  ...        Healthy                       2            Retired
# 4  ...      Unhealthy                       0           Employed
#
#    Marital Status Genetic Risk Factor (APOE-ε4 allele)  \
# 0          Single                                   No
# 1         Widowed                                   No
# 2          Single                                   No
# 3          Single                                   No
# 4         Married                                   No
#
#    Social Engagement Level Income Level Stress Levels Urban vs Rural Living  \
# 0                        1            2             0                 Urban
# 1                        0            1             0                 Urban
# 2                        1            2             0                 Rural
# 3                        0            2             1                 Rural
# 4                        1            2             0                 Rural
#
#    Alzheimer’s Diagnosis
# 0                     No
# 1                     No
# 2                     No
# 3                     No
# 4                     No
#
# [5 rows x 24 columns]

# %% [markdown]
# One hot rest

# %%
df_label= pd.get_dummies(df_label, columns=one_hot_cols, drop_first=True)
df_label.head()
# Out:
#         Age  Education Level       BMI  Physical Activity Level  \
# 0  1.321887        -1.473912  1.305564                        2
# 1 -0.069838        -0.431015  0.655286                        2
# 2  1.012615         1.654777 -0.813083                        0
# 3 -1.538881         1.307145  0.927983                        1
# 4 -1.152291        -1.126280  0.676263                        0
#
#    Cognitive Test Score  Depression Level  Sleep Quality  \
# 0              1.258648                 1              2
# 1              0.017688                 1              1
# 2             -1.074357                 0              1
# 3              0.811902                 2              0
# 4             -0.776526                 0              2
#
#    Air Pollution Exposure  Social Engagement Level  Income Level  ...  \
# 0                       0                        1             2  ...
# 1                       2                        0             1  ...
# 2                       2                        1             2  ...
# 3                       2                        0             2  ...
# 4                       0                        1             2  ...
#
#    Cholesterol Level_Normal  Alcohol Consumption_Occasionally  \
# 0                      True                              True
# 1                      True                             False
# 2                      True                              True
# 3                      True                             False
# 4                      True                             False
#
#    Alcohol Consumption_Regularly  Urban vs Rural Living_Urban  \
# 0                          False                         True
# 1                          False                         True
# 2                          False                        False
# 3                           True                        False
# 4                          False                        False
#
#    Smoking Status_Former  Smoking Status_Never  Gender_Male  \
# 0                  False                  True         True
# 1                   True                 False         True
# 2                  False                 False        False
# 3                  False                  True         True
# 4                   True                 False        False
#
#    Family History of Alzheimer’s_Yes  Diabetes_Yes  \
# 0                              False         False
# 1                              False         False
# 2                              False         False
# 3                              False          True
# 4                              False          True
#
#    Genetic Risk Factor (APOE-ε4 allele)_Yes
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
# [5 rows x 29 columns]

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87140 entries, 0 to 87139
# Data columns (total 29 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Age                                       87140 non-null  float64
#  1   Education Level                           87140 non-null  float64
#  2   BMI                                       87140 non-null  float64
#  3   Physical Activity Level                   87140 non-null  int32
#  4   Cognitive Test Score                      87140 non-null  float64
#  5   Depression Level                          87140 non-null  int32
#  6   Sleep Quality                             87140 non-null  int32
#  7   Air Pollution Exposure                    87140 non-null  int32
#  8   Social Engagement Level                   87140 non-null  int32
#  9   Income Level                              87140 non-null  int32
#  10  Stress Levels                             87140 non-null  int32
#  11  Employment Status_Retired                 87140 non-null  bool
#  12  Employment Status_Unemployed              87140 non-null  bool
#  13  Dietary Habits_Healthy                    87140 non-null  bool
#  14  Dietary Habits_Unhealthy                  87140 non-null  bool
#  15  Marital Status_Single                     87140 non-null  bool
#  16  Marital Status_Widowed                    87140 non-null  bool
#  17  Alzheimer’s Diagnosis_Yes                 87140 non-null  bool
#  18  Hypertension_Yes                          87140 non-null  bool
#  19  Cholesterol Level_Normal                  87140 non-null  bool
#  20  Alcohol Consumption_Occasionally          87140 non-null  bool
#  21  Alcohol Consumption_Regularly             87140 non-null  bool
#  22  Urban vs Rural Living_Urban               87140 non-null  bool
#  23  Smoking Status_Former                     87140 non-null  bool
#  24  Smoking Status_Never                      87140 non-null  bool
#  25  Gender_Male                               87140 non-null  bool
#  26  Family History of Alzheimer’s_Yes         87140 non-null  bool
#  27  Diabetes_Yes                              87140 non-null  bool
#  28  Genetic Risk Factor (APOE-ε4 allele)_Yes  87140 non-null  bool
# dtypes: bool(18), float64(4), int32(7)
# memory usage: 6.5 MB

# %%
label_corr = df_label.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(label_corr, ax=ax)
plt.title("Correlation between label encoded features")
plt.show()

# %% [markdown]
# There is some correlation between features, but it is usually between features like Physical Activity_Low and Physical Activity_Medium. I do not think it is worth removing these features as it could negatively impact the result. The correlation between these features is greater than -0.4 (close to 0). There are no other features correlated closely. However, there is some correlation between Age and the target variable. This should be monitored when evaluating the model.
#
# ## Dataset/Dataloader Creation

# %%
from torchvision import datasets, transforms
import torch
from torch.utils.data import Dataset, DataLoader
class BinaryDataset(Dataset):
    def __init__(self, data, labels):
        self.data = torch.tensor(data.values, dtype=torch.float32)  # Convert to tensor
        self.labels = torch.tensor(labels.values, dtype=torch.float32)  # Convert to tensor

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# %% [markdown]
# Begin with one hot encoded dataset

# %%
X_ohe = df_ohe.drop("Alzheimer’s Diagnosis_Yes", axis=1).astype("float64")
y_ohe = df_ohe["Alzheimer’s Diagnosis_Yes"]

# %%
from sklearn.model_selection import train_test_split

X_train_ohe, X_test_ohe, y_train_ohe, y_test_ohe = train_test_split(X_ohe, y_ohe, test_size=0.2, random_state=42)

# %%
print(X_train_ohe.shape)
print(y_train_ohe.shape)
print(X_test_ohe.shape)
print(y_test_ohe.shape)
# Out:
# (69712, 35)
# (69712,)
# (17428, 35)
# (17428,)

# %%
print(y_train_ohe.value_counts())
print(y_test_ohe.value_counts())
# Out:
# Alzheimer’s Diagnosis_Yes
# 0    34880
# 1    34832
# Name: count, dtype: int64
# Alzheimer’s Diagnosis_Yes
# 1    8738
# 0    8690
# Name: count, dtype: int64

# %%
ohe_train_dataset = BinaryDataset(X_train_ohe, y_train_ohe)
ohe_test_dataset = BinaryDataset(X_test_ohe, y_test_ohe)

# %%
ohe_train_dataset

# %% [markdown]
# Create DataLoader

# %%
batch_size=64
ohe_train_loader = DataLoader(ohe_train_dataset, batch_size=batch_size, shuffle=True)
ohe_test_loader = DataLoader(ohe_test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Create binary MLP class

# %%
import torch
import torch.nn as nn

class BinaryMLP(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.fc1 = nn.Linear(input_size, 256)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(256, 128)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(128, 32)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(32, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu1(out)
        out = self.fc2(out)
        out = self.relu2(out)
        out = self.fc3(out)
        out = self.relu3(out)
        out = self.fc4(out)
        out = self.sigmoid(out)
        return out  # shape (batch_size, 1)

# %%
model_ohe = BinaryMLP(35)
print(model_ohe)
# Out:
# BinaryMLP(
#   (fc1): Linear(in_features=35, out_features=256, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=128, out_features=32, bias=True)
#   (relu3): ReLU()
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# Training loop

# %%
# Training Loop for PyTorch Model
# Taken from Lecture03_MLP and Lecture09_CNN_RGB_Tensorboard in class repository

def train(model, loss_fn, optimizer, train_loader, batch_size=64, epochs=5, threshold=0.5):
    """
    A function to train a PyTorch model.
    It teaches the model to predict answers correctly by repeatedly learning from mistakes.
    
    Args:
    - model: The machine learning model to be trained.
    - loss_fn: The function that calculates how wrong the model's predictions are (loss function).
    - optimizer: The helper that adjusts the model to improve predictions (optimizer).
    - batch_size: How many examples to process at a time (default is 64).
    - epochs: How many rounds of learning the model will go through (default is 5).
    """
    
    model.train()  # Set the model to 'training mode' so it can learn and improve.

    for epoch in range(epochs):  # Loop through each learning round (epoch).
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        
        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = loss_fn(outputs.squeeze(), labels)
            loss.backward()
            optimizer.step()

            # Track training loss & accuracy
            running_loss += loss.item()
            preds = np.array((outputs.squeeze() >= threshold)).astype(int)
            correct_train += (preds == labels).sum().item()
            total_train += labels.size(0)

        # Compute epoch loss & accuracy
        train_loss = running_loss / len(train_loader)
        train_accuracy = correct_train / total_train
        
        # Print how much the model improved in this round.
        print(f"Epoch [{epoch+1}/{epochs}] - Train Loss: {train_loss:.4f} - Train Acc: {train_accuracy:.4f}")

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
model_ohe.to(device)
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# Hyperparameters and Train

# %%
lr = 0.01
epochs = 40
loss_fn = nn.BCELoss()  
optimizer = torch.optim.Adam(model_ohe.parameters())

train = train(model_ohe, loss_fn, optimizer, ohe_train_loader, batch_size, epochs)
# Out:
# Epoch [1/20] - Train Loss: 0.3313 - Train Acc: 0.8499
# Epoch [2/20] - Train Loss: 0.3148 - Train Acc: 0.8572
# Epoch [3/20] - Train Loss: 0.3020 - Train Acc: 0.8627
# Epoch [4/20] - Train Loss: 0.2916 - Train Acc: 0.8685
# Epoch [5/20] - Train Loss: 0.2820 - Train Acc: 0.8744
# Epoch [6/20] - Train Loss: 0.2693 - Train Acc: 0.8778
# Epoch [7/20] - Train Loss: 0.2629 - Train Acc: 0.8827
# Epoch [8/20] - Train Loss: 0.2530 - Train Acc: 0.8884
# Epoch [9/20] - Train Loss: 0.2462 - Train Acc: 0.8909
# Epoch [10/20] - Train Loss: 0.2380 - Train Acc: 0.8950
# Epoch [11/20] - Train Loss: 0.2340 - Train Acc: 0.8968
# Epoch [12/20] - Train Loss: 0.2228 - Train Acc: 0.9021
# Epoch [13/20] - Train Loss: 0.2154 - Train Acc: 0.9059
# Epoch [14/20] - Train Loss: 0.2171 - Train Acc: 0.9055
# Epoch [15/20] - Train Loss: 0.2043 - Train Acc: 0.9124
# Epoch [16/20] - Train Loss: 0.2023 - Train Acc: 0.9134
# Epoch [17/20] - Train Loss: 0.1912 - Train Acc: 0.9173
# Epoch [18/20] - Train Loss: 0.1899 - Train Acc: 0.9173
# Epoch [19/20] - Train Loss: 0.1845 - Train Acc: 0.9212
# Epoch [20/20] - Train Loss: 0.1818 - Train Acc: 0.9226

# %% [markdown]
# Inference

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# function for seeing the model's accuracy on the test set
def test(model, test_loader, threshold=0.5):
    # Running inference
    model.eval()  # Set the model to evaluation mode (disables dropout, etc.)
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []


    with torch.no_grad():  # Disable gradient computation for efficiency
        for inputs, labels in test_loader:
            # for accuracy
            outputs = model(inputs)
            preds = (outputs.squeeze().numpy() >= threshold).astype(int)
            total += labels.size(0)
            correct += (preds == labels).sum().item()
            # for confusion matrix
            all_labels.extend(labels.numpy())
            all_predictions.extend(preds)

    accuracy = correct / total * 100
    print(f"Accuracy: {accuracy:.2f}%")
    
    cm = confusion_matrix(all_labels, all_predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(range(2)))
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.show()

# %%
test(model_ohe, ohe_test_loader)
# Out:
# Accuracy: 71.24%

# %%
torch.save(model_ohe.state_dict(), "one_hot_model.pth")
print("Final model saved.")
# Out:
# Final model saved.

# %% [markdown]
# Label Encoded Dataset

# %%
X_label = df_label.drop("Alzheimer’s Diagnosis_Yes", axis=1).astype("float64")
y_label = df_label["Alzheimer’s Diagnosis_Yes"]

X_train_label, X_test_label, y_train_label, y_test_label = train_test_split(X_label, y_label, test_size=0.2, random_state=42)

label_train_dataset = BinaryDataset(X_train_label, y_train_label)
label_test_dataset = BinaryDataset(X_test_label, y_test_label)

label_train_loader = DataLoader(label_train_dataset, batch_size=batch_size, shuffle=True)
label_test_loader = DataLoader(label_test_dataset, batch_size=batch_size, shuffle=False)

model_label = BinaryMLP(X_label.shape[1])
print(model_label)
# Out:
# BinaryMLP(
#   (fc1): Linear(in_features=28, out_features=256, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=128, out_features=32, bias=True)
#   (relu3): ReLU()
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
lr = 0.01
epochs = 20
loss_fn = nn.BCELoss()  
optimizer = torch.optim.Adam(model_label.parameters())

train_label = train(model_label, loss_fn, optimizer, label_train_loader, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch [1/20] - Train Loss: 0.5158 - Train Acc: 0.7378
# Epoch [2/20] - Train Loss: 0.5084 - Train Acc: 0.7417
# Epoch [3/20] - Train Loss: 0.4994 - Train Acc: 0.7451
# Epoch [4/20] - Train Loss: 0.4899 - Train Acc: 0.7511
# Epoch [5/20] - Train Loss: 0.4778 - Train Acc: 0.7572
# Epoch [6/20] - Train Loss: 0.4660 - Train Acc: 0.7659
# Epoch [7/20] - Train Loss: 0.4526 - Train Acc: 0.7752
# Epoch [8/20] - Train Loss: 0.4384 - Train Acc: 0.7828
# Epoch [9/20] - Train Loss: 0.4254 - Train Acc: 0.7911
# Epoch [10/20] - Train Loss: 0.4113 - Train Acc: 0.7993
# Epoch [11/20] - Train Loss: 0.3967 - Train Acc: 0.8077
# Epoch [12/20] - Train Loss: 0.3849 - Train Acc: 0.8150
# Epoch [13/20] - Train Loss: 0.3700 - Train Acc: 0.8241
# Epoch [14/20] - Train Loss: 0.3586 - Train Acc: 0.8297
# Epoch [15/20] - Train Loss: 0.3476 - Train Acc: 0.8367
# Epoch [16/20] - Train Loss: 0.3353 - Train Acc: 0.8422
# Epoch [17/20] - Train Loss: 0.3251 - Train Acc: 0.8480
# Epoch [18/20] - Train Loss: 0.3152 - Train Acc: 0.8534
# Epoch [19/20] - Train Loss: 0.3047 - Train Acc: 0.8593
# Epoch [20/20] - Train Loss: 0.2958 - Train Acc: 0.8637

# %%
test(model_label, label_test_loader)
# Out:
# Accuracy: 70.20%

# %%
torch.save(model_label.state_dict(), "label_encoded_model.pth")
print("Final model saved.")
# Out:
# Final model saved.
