# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
import seaborn as sns

# %%
df = pd.read_csv("data/alzheimers_prediction_dataset.csv")

# %%
df.head()
# Out:
#         Country  Age  Gender  Education Level   BMI Physical Activity Level  \
# 0         Spain   90    Male                1  33.0                  Medium
# 1     Argentina   72    Male                7  29.9                  Medium
# 2  South Africa   86  Female               19  22.9                    High
# 3         China   53    Male               17  31.2                     Low
# 4        Sweden   58  Female                3  30.0                    High
#
#   Smoking Status Alcohol Consumption Diabetes Hypertension  ...  \
# 0          Never        Occasionally       No           No  ...
# 1         Former               Never       No           No  ...
# 2        Current        Occasionally       No          Yes  ...
# 3          Never           Regularly      Yes           No  ...
# 4         Former               Never      Yes           No  ...
#
#   Dietary Habits Air Pollution Exposure  Employment Status Marital Status  \
# 0        Healthy                   High            Retired         Single
# 1        Healthy                 Medium         Unemployed        Widowed
# 2        Average                 Medium           Employed         Single
# 3        Healthy                 Medium            Retired         Single
# 4      Unhealthy                   High           Employed        Married
#
#   Genetic Risk Factor (APOE-ε4 allele) Social Engagement Level Income Level  \
# 0                                   No                     Low       Medium
# 1                                   No                    High          Low
# 2                                   No                     Low       Medium
# 3                                   No                    High       Medium
# 4                                   No                     Low       Medium
#
#   Stress Levels Urban vs Rural Living Alzheimer’s Diagnosis
# 0          High                 Urban                    No
# 1          High                 Urban                    No
# 2          High                 Rural                    No
# 3           Low                 Rural                    No
# 4          High                 Rural                    No
#
# [5 rows x 25 columns]

# %%
size = df.shape[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74283 entries, 0 to 74282
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               74283 non-null  object
#  1   Age                                   74283 non-null  int64
#  2   Gender                                74283 non-null  object
#  3   Education Level                       74283 non-null  int64
#  4   BMI                                   74283 non-null  float64
#  5   Physical Activity Level               74283 non-null  object
#  6   Smoking Status                        74283 non-null  object
#  7   Alcohol Consumption                   74283 non-null  object
#  8   Diabetes                              74283 non-null  object
#  9   Hypertension                          74283 non-null  object
#  10  Cholesterol Level                     74283 non-null  object
#  11  Family History of Alzheimer’s         74283 non-null  object
#  12  Cognitive Test Score                  74283 non-null  int64
#  13  Depression Level                      74283 non-null  object
#  14  Sleep Quality                         74283 non-null  object
#  15  Dietary Habits                        74283 non-null  object
#  16  Air Pollution Exposure                74283 non-null  object
#  17  Employment Status                     74283 non-null  object
#  18  Marital Status                        74283 non-null  object
#  19  Genetic Risk Factor (APOE-ε4 allele)  74283 non-null  object
#  20  Social Engagement Level               74283 non-null  object
#  21  Income Level                          74283 non-null  object
#  22  Stress Levels                         74283 non-null  object
#  23  Urban vs Rural Living                 74283 non-null  object
#  24  Alzheimer’s Diagnosis                 74283 non-null  object
# dtypes: float64(1), int64(3), object(21)
# memory usage: 14.2+ MB

# %% [markdown]
# No columns have any null values

# %%
df.describe()
# Out:
#                 Age  Education Level           BMI  Cognitive Test Score
# count  74283.000000     74283.000000  74283.000000          74283.000000
# mean      71.964703         9.487514     26.780639             64.654241
# std       12.980748         5.757020      4.764679             20.153247
# min       50.000000         0.000000     18.500000             30.000000
# 25%       61.000000         4.000000     22.700000             47.000000
# 50%       72.000000         9.000000     26.800000             65.000000
# 75%       83.000000        14.000000     30.900000             82.000000
# max       94.000000        19.000000     35.000000             99.000000

# %% [markdown]
# Some range in values, will use standard scalar to fix this because there is no reason to not use another (not a big range, not highly skewed)

# %%
scaler = StandardScaler()
numerical_cols = ["Age", "Education Level", "BMI", "Cognitive Test Score"]
df_numerical = df[numerical_cols]
scaled = scaler.fit_transform(df_numerical)
df[numerical_cols] = scaled
df.describe()
# Out:
#                 Age  Education Level           BMI  Cognitive Test Score
# count  7.428300e+04     7.428300e+04  7.428300e+04          7.428300e+04
# mean   2.133073e-17     5.452248e-17 -2.495360e-16         -2.587427e-16
# std    1.000007e+00     1.000007e+00  1.000007e+00          1.000007e+00
# min   -1.692110e+00    -1.648002e+00 -1.737933e+00         -1.719548e+00
# 25%   -8.446953e-01    -9.531929e-01 -8.564409e-01         -8.760057e-01
# 50%    2.719233e-03    -8.468222e-02  4.063489e-03          1.715660e-02
# 75%    8.501337e-01     7.838285e-01  8.645679e-01          8.606988e-01
# max    1.697548e+00     1.652339e+00  1.725072e+00          1.704241e+00

# %%
df.describe(include="object")
# Out:
#        Country  Gender Physical Activity Level Smoking Status  \
# count    74283   74283                   74283          74283
# unique      20       2                       3              3
# top     Brazil  Female                    High        Current
# freq      3839   37249                   24853          24915
#
#        Alcohol Consumption Diabetes Hypertension Cholesterol Level  \
# count                74283    74283        74283             74283
# unique                   3        2            2                 2
# top                  Never       No           No            Normal
# freq                 24865    59527        52134             51973
#
#        Family History of Alzheimer’s Depression Level  ... Dietary Habits  \
# count                          74283            74283  ...          74283
# unique                             2                3  ...              3
# top                               No           Medium  ...        Average
# freq                           52004            24843  ...          24917
#
#        Air Pollution Exposure Employment Status Marital Status  \
# count                   74283             74283          74283
# unique                      3                 3              3
# top                      High        Unemployed         Single
# freq                    24906             24801          25169
#
#        Genetic Risk Factor (APOE-ε4 allele) Social Engagement Level  \
# count                                 74283                   74283
# unique                                    2                       3
# top                                      No                  Medium
# freq                                  59561                   24859
#
#        Income Level Stress Levels Urban vs Rural Living Alzheimer’s Diagnosis
# count         74283         74283                 74283                 74283
# unique            3             3                     2                     2
# top             Low        Medium                 Rural                    No
# freq          24873         24886                 37203                 43570
#
# [4 rows x 21 columns]

# %% [markdown]
# Country will get dropped because there are too many values to encode. This would lead to curse of dimensionality or the model creating an ordinal relationship between countries when one does not exist. Also, should not contribute to target variable.

# %%
df = df.drop(columns=["Country"])

# %%
df.describe(include="object")
# Out:
#         Gender Physical Activity Level Smoking Status Alcohol Consumption  \
# count    74283                   74283          74283               74283
# unique       2                       3              3                   3
# top     Female                    High        Current               Never
# freq     37249                   24853          24915               24865
#
#        Diabetes Hypertension Cholesterol Level Family History of Alzheimer’s  \
# count     74283        74283             74283                         74283
# unique        2            2                 2                             2
# top          No           No            Normal                            No
# freq      59527        52134             51973                         52004
#
#        Depression Level Sleep Quality Dietary Habits Air Pollution Exposure  \
# count             74283         74283          74283                  74283
# unique                3             3              3                      3
# top              Medium          Good        Average                   High
# freq              24843         25145          24917                  24906
#
#        Employment Status Marital Status Genetic Risk Factor (APOE-ε4 allele)  \
# count              74283          74283                                74283
# unique                 3              3                                    2
# top           Unemployed         Single                                   No
# freq               24801          25169                                59561
#
#        Social Engagement Level Income Level Stress Levels  \
# count                    74283        74283         74283
# unique                       3            3             3
# top                     Medium          Low        Medium
# freq                     24859        24873         24886
#
#        Urban vs Rural Living Alzheimer’s Diagnosis
# count                  74283                 74283
# unique                     2                     2
# top                    Rural                    No
# freq                   37203                 43570

# %% [markdown]
# All columns with only 2 or 3 values. This means one-hot encoding should work for most. However, for columns like physical activity, cholesterol, Depression, Air pollution, the labels are along the lines of low, medium, and high. This means label encoding is suitable for these columns as there is an ordinal relationship between the values.

# %%
print("Unique values for:\nAlcohol Consumption: ", df["Alcohol Consumption"].unique()) # one-hot
print("Smoking Status: ", df["Smoking Status"].unique()) # one-hot
print("Depression Level: ", df["Depression Level"].unique()) # try label
print("Dietary Habits: ", df["Dietary Habits"].unique()) # one-hot
print("Employment Status: ", df["Employment Status"].unique()) # one-hot
print("Marital Status: ", df["Marital Status"].unique()) # one-hot
print("Social Engagement Level: ", df["Social Engagement Level"].unique()) # try label
# Out:
# Unique values for:
# Alcohol Consumption:  ['Occasionally' 'Never' 'Regularly']
# Smoking Status:  ['Never' 'Former' 'Current']
# Depression Level:  ['Low' 'High' 'Medium']
# Dietary Habits:  ['Healthy' 'Average' 'Unhealthy']
# Employment Status:  ['Retired' 'Unemployed' 'Employed']
# Marital Status:  ['Single' 'Widowed' 'Married']
# Social Engagement Level:  ['Low' 'High' 'Medium']

# %%
object_cols = df.select_dtypes("object").columns.tolist()
label_enc_cols = ["Physical Activity Level", "Depression Level", "Sleep Quality",  "Air Pollution Exposure",
                 "Social Engagement Level", "Income Level", "Stress Levels"] 
one_hot_cols = list(set(object_cols) - set(label_enc_cols))
# try doing label encoding to see if it is better than one-hot for all

# %%
df_ohe = pd.get_dummies(df, columns=object_cols, drop_first=True)
df_ohe.head()
# Out:
#         Age  Education Level       BMI  Cognitive Test Score  Gender_Male  \
# 0  1.389398        -1.474299  1.305314              1.257660         True
# 1  0.002719        -0.432087  0.654689              0.017157         True
# 2  1.081247         1.652339 -0.814465             -1.074486        False
# 3 -1.460997         1.304935  0.927532              0.811079         True
# 4 -1.075808        -1.126895  0.675677             -0.776765        False
#
#    Physical Activity Level_Low  Physical Activity Level_Medium  \
# 0                        False                            True
# 1                        False                            True
# 2                        False                           False
# 3                         True                           False
# 4                        False                           False
#
#    Smoking Status_Former  Smoking Status_Never  \
# 0                  False                  True
# 1                   True                 False
# 2                  False                 False
# 3                  False                  True
# 4                   True                 False
#
#    Alcohol Consumption_Occasionally  ...  Marital Status_Widowed  \
# 0                              True  ...                   False
# 1                             False  ...                    True
# 2                              True  ...                   False
# 3                             False  ...                   False
# 4                             False  ...                   False
#
#    Genetic Risk Factor (APOE-ε4 allele)_Yes  Social Engagement Level_Low  \
# 0                                     False                         True
# 1                                     False                        False
# 2                                     False                         True
# 3                                     False                        False
# 4                                     False                         True
#
#    Social Engagement Level_Medium  Income Level_Low  Income Level_Medium  \
# 0                           False             False                 True
# 1                           False              True                False
# 2                           False             False                 True
# 3                           False             False                 True
# 4                           False             False                 True
#
#    Stress Levels_Low  Stress Levels_Medium  Urban vs Rural Living_Urban  \
# 0              False                 False                         True
# 1              False                 False                         True
# 2              False                 False                        False
# 3               True                 False                        False
# 4              False                 False                        False
#
#    Alzheimer’s Diagnosis_Yes
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
#
# [5 rows x 36 columns]

# %%
df_label = df.copy()

# %%
le = LabelEncoder()
for col in label_enc_cols:
    df_label[col] = le.fit_transform(df[col])
df_label.head()
# Out:
#         Age  Gender  Education Level       BMI  Physical Activity Level  \
# 0  1.389398    Male        -1.474299  1.305314                        2
# 1  0.002719    Male        -0.432087  0.654689                        2
# 2  1.081247  Female         1.652339 -0.814465                        0
# 3 -1.460997    Male         1.304935  0.927532                        1
# 4 -1.075808  Female        -1.126895  0.675677                        0
#
#   Smoking Status Alcohol Consumption Diabetes Hypertension Cholesterol Level  \
# 0          Never        Occasionally       No           No            Normal
# 1         Former               Never       No           No            Normal
# 2        Current        Occasionally       No          Yes            Normal
# 3          Never           Regularly      Yes           No            Normal
# 4         Former               Never      Yes           No            Normal
#
#    ... Dietary Habits  Air Pollution Exposure  Employment Status  \
# 0  ...        Healthy                       0            Retired
# 1  ...        Healthy                       2         Unemployed
# 2  ...        Average                       2           Employed
# 3  ...        Healthy                       2            Retired
# 4  ...      Unhealthy                       0           Employed
#
#    Marital Status Genetic Risk Factor (APOE-ε4 allele)  \
# 0          Single                                   No
# 1         Widowed                                   No
# 2          Single                                   No
# 3          Single                                   No
# 4         Married                                   No
#
#    Social Engagement Level Income Level Stress Levels Urban vs Rural Living  \
# 0                        1            2             0                 Urban
# 1                        0            1             0                 Urban
# 2                        1            2             0                 Rural
# 3                        0            2             1                 Rural
# 4                        1            2             0                 Rural
#
#    Alzheimer’s Diagnosis
# 0                     No
# 1                     No
# 2                     No
# 3                     No
# 4                     No
#
# [5 rows x 24 columns]

# %% [markdown]
# One hot rest

# %%
df_label= pd.get_dummies(df_label, columns=one_hot_cols, drop_first=True)
df_label.head()
# Out:
#         Age  Education Level       BMI  Physical Activity Level  \
# 0  1.389398        -1.474299  1.305314                        2
# 1  0.002719        -0.432087  0.654689                        2
# 2  1.081247         1.652339 -0.814465                        0
# 3 -1.460997         1.304935  0.927532                        1
# 4 -1.075808        -1.126895  0.675677                        0
#
#    Cognitive Test Score  Depression Level  Sleep Quality  \
# 0              1.257660                 1              2
# 1              0.017157                 1              1
# 2             -1.074486                 0              1
# 3              0.811079                 2              0
# 4             -0.776765                 0              2
#
#    Air Pollution Exposure  Social Engagement Level  Income Level  ...  \
# 0                       0                        1             2  ...
# 1                       2                        0             1  ...
# 2                       2                        1             2  ...
# 3                       2                        0             2  ...
# 4                       0                        1             2  ...
#
#    Marital Status_Widowed  Gender_Male  Employment Status_Retired  \
# 0                   False         True                       True
# 1                    True         True                      False
# 2                   False        False                      False
# 3                   False         True                       True
# 4                   False        False                      False
#
#    Employment Status_Unemployed  Genetic Risk Factor (APOE-ε4 allele)_Yes  \
# 0                         False                                     False
# 1                          True                                     False
# 2                         False                                     False
# 3                         False                                     False
# 4                         False                                     False
#
#    Cholesterol Level_Normal  Smoking Status_Former  Smoking Status_Never  \
# 0                      True                  False                  True
# 1                      True                   True                 False
# 2                      True                  False                 False
# 3                      True                  False                  True
# 4                      True                   True                 False
#
#    Family History of Alzheimer’s_Yes  Diabetes_Yes
# 0                              False         False
# 1                              False         False
# 2                              False         False
# 3                              False          True
# 4                              False          True
#
# [5 rows x 29 columns]

# %%
label_corr = df_label.corr()
sns.heatmap(label_corr)
plt.title("Correlation between label encoded features")
plt.show()

# %%
hot_corr = df_ohe.corr()
sns.heatmap(hot_corr)
plt.title("Correlation between one-hot encoded features")
plt.show()

# %%
print((np.abs(hot_corr) > 0.4) == True)
# Out:
#                                             Age  Education Level    BMI  \
# Age                                        True            False  False
# Education Level                           False             True  False
# BMI                                       False            False   True
# Cognitive Test Score                      False            False  False
# Gender_Male                               False            False  False
# Physical Activity Level_Low               False            False  False
# Physical Activity Level_Medium            False            False  False
# Smoking Status_Former                     False            False  False
# Smoking Status_Never                      False            False  False
# Alcohol Consumption_Occasionally          False            False  False
# Alcohol Consumption_Regularly             False            False  False
# Diabetes_Yes                              False            False  False
# Hypertension_Yes                          False            False  False
# Cholesterol Level_Normal                  False            False  False
# Family History of Alzheimer’s_Yes         False            False  False
# Depression Level_Low                      False            False  False
# Depression Level_Medium                   False            False  False
# Sleep Quality_Good                        False            False  False
# Sleep Quality_Poor                        False            False  False
# Dietary Habits_Healthy                    False            False  False
# Dietary Habits_Unhealthy                  False            False  False
# Air Pollution Exposure_Low                False            False  False
# Air Pollution Exposure_Medium             False            False  False
# Employment Status_Retired                 False            False  False
# Employment Status_Unemployed              False            False  False
# Marital Status_Single                     False            False  False
# Marital Status_Widowed                    False            False  False
# Genetic Risk Factor (APOE-ε4 allele)_Yes  False            False  False
# Social Engagement Level_Low               False            False  False
# Social Engagement Level_Medium            False            False  False
# Income Level_Low                          False            False  False
# Income Level_Medium                       False            False  False
# Stress Levels_Low                         False            False  False
# Stress Levels_Medium                      False            False  False
# Urban vs Rural Living_Urban               False            False  False
# Alzheimer’s Diagnosis_Yes                  True            False  False
#
#                                           Cognitive Test Score  Gender_Male  \
# Age                                                      False        False
# Education Level                                          False        False
# BMI                                                      False        False
# Cognitive Test Score                                      True        False
# Gender_Male                                              False         True
# Physical Activity Level_Low                              False        False
# Physical Activity Level_Medium                           False        False
# Smoking Status_Former                                    False        False
# Smoking Status_Never                                     False        False
# Alcohol Consumption_Occasionally                         False        False
# Alcohol Consumption_Regularly                            False        False
# Diabetes_Yes                                             False        False
# Hypertension_Yes                                         False        False
# Cholesterol Level_Normal                                 False        False
# Family History of Alzheimer’s_Yes                        False        False
# Depression Level_Low                                     False        False
# Depression Level_Medium                                  False        False
# Sleep Quality_Good                                       False        False
# Sleep Quality_Poor                                       False        False
# Dietary Habits_Healthy                                   False        False
# Dietary Habits_Unhealthy                                 False        False
# Air Pollution Exposure_Low                               False        False
# Air Pollution Exposure_Medium                            False        False
# Employment Status_Retired                                False        False
# Employment Status_Unemployed                             False        False
# Marital Status_Single                                    False        False
# Marital Status_Widowed                                   False        False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                 False        False
# Social Engagement Level_Low                              False        False
# Social Engagement Level_Medium                           False        False
# Income Level_Low                                         False        False
# Income Level_Medium                                      False        False
# Stress Levels_Low                                        False        False
# Stress Levels_Medium                                     False        False
# Urban vs Rural Living_Urban                              False        False
# Alzheimer’s Diagnosis_Yes                                False        False
#
#                                           Physical Activity Level_Low  \
# Age                                                             False
# Education Level                                                 False
# BMI                                                             False
# Cognitive Test Score                                            False
# Gender_Male                                                     False
# Physical Activity Level_Low                                      True
# Physical Activity Level_Medium                                   True
# Smoking Status_Former                                           False
# Smoking Status_Never                                            False
# Alcohol Consumption_Occasionally                                False
# Alcohol Consumption_Regularly                                   False
# Diabetes_Yes                                                    False
# Hypertension_Yes                                                False
# Cholesterol Level_Normal                                        False
# Family History of Alzheimer’s_Yes                               False
# Depression Level_Low                                            False
# Depression Level_Medium                                         False
# Sleep Quality_Good                                              False
# Sleep Quality_Poor                                              False
# Dietary Habits_Healthy                                          False
# Dietary Habits_Unhealthy                                        False
# Air Pollution Exposure_Low                                      False
# Air Pollution Exposure_Medium                                   False
# Employment Status_Retired                                       False
# Employment Status_Unemployed                                    False
# Marital Status_Single                                           False
# Marital Status_Widowed                                          False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                        False
# Social Engagement Level_Low                                     False
# Social Engagement Level_Medium                                  False
# Income Level_Low                                                False
# Income Level_Medium                                             False
# Stress Levels_Low                                               False
# Stress Levels_Medium                                            False
# Urban vs Rural Living_Urban                                     False
# Alzheimer’s Diagnosis_Yes                                       False
#
#                                           Physical Activity Level_Medium  \
# Age                                                                False
# Education Level                                                    False
# BMI                                                                False
# Cognitive Test Score                                               False
# Gender_Male                                                        False
# Physical Activity Level_Low                                         True
# Physical Activity Level_Medium                                      True
# Smoking Status_Former                                              False
# Smoking Status_Never                                               False
# Alcohol Consumption_Occasionally                                   False
# Alcohol Consumption_Regularly                                      False
# Diabetes_Yes                                                       False
# Hypertension_Yes                                                   False
# Cholesterol Level_Normal                                           False
# Family History of Alzheimer’s_Yes                                  False
# Depression Level_Low                                               False
# Depression Level_Medium                                            False
# Sleep Quality_Good                                                 False
# Sleep Quality_Poor                                                 False
# Dietary Habits_Healthy                                             False
# Dietary Habits_Unhealthy                                           False
# Air Pollution Exposure_Low                                         False
# Air Pollution Exposure_Medium                                      False
# Employment Status_Retired                                          False
# Employment Status_Unemployed                                       False
# Marital Status_Single                                              False
# Marital Status_Widowed                                             False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                           False
# Social Engagement Level_Low                                        False
# Social Engagement Level_Medium                                     False
# Income Level_Low                                                   False
# Income Level_Medium                                                False
# Stress Levels_Low                                                  False
# Stress Levels_Medium                                               False
# Urban vs Rural Living_Urban                                        False
# Alzheimer’s Diagnosis_Yes                                          False
#
#                                           Smoking Status_Former  \
# Age                                                       False
# Education Level                                           False
# BMI                                                       False
# Cognitive Test Score                                      False
# Gender_Male                                               False
# Physical Activity Level_Low                               False
# Physical Activity Level_Medium                            False
# Smoking Status_Former                                      True
# Smoking Status_Never                                       True
# Alcohol Consumption_Occasionally                          False
# Alcohol Consumption_Regularly                             False
# Diabetes_Yes                                              False
# Hypertension_Yes                                          False
# Cholesterol Level_Normal                                  False
# Family History of Alzheimer’s_Yes                         False
# Depression Level_Low                                      False
# Depression Level_Medium                                   False
# Sleep Quality_Good                                        False
# Sleep Quality_Poor                                        False
# Dietary Habits_Healthy                                    False
# Dietary Habits_Unhealthy                                  False
# Air Pollution Exposure_Low                                False
# Air Pollution Exposure_Medium                             False
# Employment Status_Retired                                 False
# Employment Status_Unemployed                              False
# Marital Status_Single                                     False
# Marital Status_Widowed                                    False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                  False
# Social Engagement Level_Low                               False
# Social Engagement Level_Medium                            False
# Income Level_Low                                          False
# Income Level_Medium                                       False
# Stress Levels_Low                                         False
# Stress Levels_Medium                                      False
# Urban vs Rural Living_Urban                               False
# Alzheimer’s Diagnosis_Yes                                 False
#
#                                           Smoking Status_Never  \
# Age                                                      False
# Education Level                                          False
# BMI                                                      False
# Cognitive Test Score                                     False
# Gender_Male                                              False
# Physical Activity Level_Low                              False
# Physical Activity Level_Medium                           False
# Smoking Status_Former                                     True
# Smoking Status_Never                                      True
# Alcohol Consumption_Occasionally                         False
# Alcohol Consumption_Regularly                            False
# Diabetes_Yes                                             False
# Hypertension_Yes                                         False
# Cholesterol Level_Normal                                 False
# Family History of Alzheimer’s_Yes                        False
# Depression Level_Low                                     False
# Depression Level_Medium                                  False
# Sleep Quality_Good                                       False
# Sleep Quality_Poor                                       False
# Dietary Habits_Healthy                                   False
# Dietary Habits_Unhealthy                                 False
# Air Pollution Exposure_Low                               False
# Air Pollution Exposure_Medium                            False
# Employment Status_Retired                                False
# Employment Status_Unemployed                             False
# Marital Status_Single                                    False
# Marital Status_Widowed                                   False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                 False
# Social Engagement Level_Low                              False
# Social Engagement Level_Medium                           False
# Income Level_Low                                         False
# Income Level_Medium                                      False
# Stress Levels_Low                                        False
# Stress Levels_Medium                                     False
# Urban vs Rural Living_Urban                              False
# Alzheimer’s Diagnosis_Yes                                False
#
#                                           Alcohol Consumption_Occasionally  \
# Age                                                                  False
# Education Level                                                      False
# BMI                                                                  False
# Cognitive Test Score                                                 False
# Gender_Male                                                          False
# Physical Activity Level_Low                                          False
# Physical Activity Level_Medium                                       False
# Smoking Status_Former                                                False
# Smoking Status_Never                                                 False
# Alcohol Consumption_Occasionally                                      True
# Alcohol Consumption_Regularly                                         True
# Diabetes_Yes                                                         False
# Hypertension_Yes                                                     False
# Cholesterol Level_Normal                                             False
# Family History of Alzheimer’s_Yes                                    False
# Depression Level_Low                                                 False
# Depression Level_Medium                                              False
# Sleep Quality_Good                                                   False
# Sleep Quality_Poor                                                   False
# Dietary Habits_Healthy                                               False
# Dietary Habits_Unhealthy                                             False
# Air Pollution Exposure_Low                                           False
# Air Pollution Exposure_Medium                                        False
# Employment Status_Retired                                            False
# Employment Status_Unemployed                                         False
# Marital Status_Single                                                False
# Marital Status_Widowed                                               False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                             False
# Social Engagement Level_Low                                          False
# Social Engagement Level_Medium                                       False
# Income Level_Low                                                     False
# Income Level_Medium                                                  False
# Stress Levels_Low                                                    False
# Stress Levels_Medium                                                 False
# Urban vs Rural Living_Urban                                          False
# Alzheimer’s Diagnosis_Yes                                            False
#
#                                           ...  Marital Status_Widowed  \
# Age                                       ...                   False
# Education Level                           ...                   False
# BMI                                       ...                   False
# Cognitive Test Score                      ...                   False
# Gender_Male                               ...                   False
# Physical Activity Level_Low               ...                   False
# Physical Activity Level_Medium            ...                   False
# Smoking Status_Former                     ...                   False
# Smoking Status_Never                      ...                   False
# Alcohol Consumption_Occasionally          ...                   False
# Alcohol Consumption_Regularly             ...                   False
# Diabetes_Yes                              ...                   False
# Hypertension_Yes                          ...                   False
# Cholesterol Level_Normal                  ...                   False
# Family History of Alzheimer’s_Yes         ...                   False
# Depression Level_Low                      ...                   False
# Depression Level_Medium                   ...                   False
# Sleep Quality_Good                        ...                   False
# Sleep Quality_Poor                        ...                   False
# Dietary Habits_Healthy                    ...                   False
# Dietary Habits_Unhealthy                  ...                   False
# Air Pollution Exposure_Low                ...                   False
# Air Pollution Exposure_Medium             ...                   False
# Employment Status_Retired                 ...                   False
# Employment Status_Unemployed              ...                   False
# Marital Status_Single                     ...                    True
# Marital Status_Widowed                    ...                    True
# Genetic Risk Factor (APOE-ε4 allele)_Yes  ...                   False
# Social Engagement Level_Low               ...                   False
# Social Engagement Level_Medium            ...                   False
# Income Level_Low                          ...                   False
# Income Level_Medium                       ...                   False
# Stress Levels_Low                         ...                   False
# Stress Levels_Medium                      ...                   False
# Urban vs Rural Living_Urban               ...                   False
# Alzheimer’s Diagnosis_Yes                 ...                   False
#
#                                           Genetic Risk Factor (APOE-ε4 allele)_Yes  \
# Age                                                                          False
# Education Level                                                              False
# BMI                                                                          False
# Cognitive Test Score                                                         False
# Gender_Male                                                                  False
# Physical Activity Level_Low                                                  False
# Physical Activity Level_Medium                                               False
# Smoking Status_Former                                                        False
# Smoking Status_Never                                                         False
# Alcohol Consumption_Occasionally                                             False
# Alcohol Consumption_Regularly                                                False
# Diabetes_Yes                                                                 False
# Hypertension_Yes                                                             False
# Cholesterol Level_Normal                                                     False
# Family History of Alzheimer’s_Yes                                            False
# Depression Level_Low                                                         False
# Depression Level_Medium                                                      False
# Sleep Quality_Good                                                           False
# Sleep Quality_Poor                                                           False
# Dietary Habits_Healthy                                                       False
# Dietary Habits_Unhealthy                                                     False
# Air Pollution Exposure_Low                                                   False
# Air Pollution Exposure_Medium                                                False
# Employment Status_Retired                                                    False
# Employment Status_Unemployed                                                 False
# Marital Status_Single                                                        False
# Marital Status_Widowed                                                       False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                                      True
# Social Engagement Level_Low                                                  False
# Social Engagement Level_Medium                                               False
# Income Level_Low                                                             False
# Income Level_Medium                                                          False
# Stress Levels_Low                                                            False
# Stress Levels_Medium                                                         False
# Urban vs Rural Living_Urban                                                  False
# Alzheimer’s Diagnosis_Yes                                                    False
#
#                                           Social Engagement Level_Low  \
# Age                                                             False
# Education Level                                                 False
# BMI                                                             False
# Cognitive Test Score                                            False
# Gender_Male                                                     False
# Physical Activity Level_Low                                     False
# Physical Activity Level_Medium                                  False
# Smoking Status_Former                                           False
# Smoking Status_Never                                            False
# Alcohol Consumption_Occasionally                                False
# Alcohol Consumption_Regularly                                   False
# Diabetes_Yes                                                    False
# Hypertension_Yes                                                False
# Cholesterol Level_Normal                                        False
# Family History of Alzheimer’s_Yes                               False
# Depression Level_Low                                            False
# Depression Level_Medium                                         False
# Sleep Quality_Good                                              False
# Sleep Quality_Poor                                              False
# Dietary Habits_Healthy                                          False
# Dietary Habits_Unhealthy                                        False
# Air Pollution Exposure_Low                                      False
# Air Pollution Exposure_Medium                                   False
# Employment Status_Retired                                       False
# Employment Status_Unemployed                                    False
# Marital Status_Single                                           False
# Marital Status_Widowed                                          False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                        False
# Social Engagement Level_Low                                      True
# Social Engagement Level_Medium                                   True
# Income Level_Low                                                False
# Income Level_Medium                                             False
# Stress Levels_Low                                               False
# Stress Levels_Medium                                            False
# Urban vs Rural Living_Urban                                     False
# Alzheimer’s Diagnosis_Yes                                       False
#
#                                           Social Engagement Level_Medium  \
# Age                                                                False
# Education Level                                                    False
# BMI                                                                False
# Cognitive Test Score                                               False
# Gender_Male                                                        False
# Physical Activity Level_Low                                        False
# Physical Activity Level_Medium                                     False
# Smoking Status_Former                                              False
# Smoking Status_Never                                               False
# Alcohol Consumption_Occasionally                                   False
# Alcohol Consumption_Regularly                                      False
# Diabetes_Yes                                                       False
# Hypertension_Yes                                                   False
# Cholesterol Level_Normal                                           False
# Family History of Alzheimer’s_Yes                                  False
# Depression Level_Low                                               False
# Depression Level_Medium                                            False
# Sleep Quality_Good                                                 False
# Sleep Quality_Poor                                                 False
# Dietary Habits_Healthy                                             False
# Dietary Habits_Unhealthy                                           False
# Air Pollution Exposure_Low                                         False
# Air Pollution Exposure_Medium                                      False
# Employment Status_Retired                                          False
# Employment Status_Unemployed                                       False
# Marital Status_Single                                              False
# Marital Status_Widowed                                             False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                           False
# Social Engagement Level_Low                                         True
# Social Engagement Level_Medium                                      True
# Income Level_Low                                                   False
# Income Level_Medium                                                False
# Stress Levels_Low                                                  False
# Stress Levels_Medium                                               False
# Urban vs Rural Living_Urban                                        False
# Alzheimer’s Diagnosis_Yes                                          False
#
#                                           Income Level_Low  \
# Age                                                  False
# Education Level                                      False
# BMI                                                  False
# Cognitive Test Score                                 False
# Gender_Male                                          False
# Physical Activity Level_Low                          False
# Physical Activity Level_Medium                       False
# Smoking Status_Former                                False
# Smoking Status_Never                                 False
# Alcohol Consumption_Occasionally                     False
# Alcohol Consumption_Regularly                        False
# Diabetes_Yes                                         False
# Hypertension_Yes                                     False
# Cholesterol Level_Normal                             False
# Family History of Alzheimer’s_Yes                    False
# Depression Level_Low                                 False
# Depression Level_Medium                              False
# Sleep Quality_Good                                   False
# Sleep Quality_Poor                                   False
# Dietary Habits_Healthy                               False
# Dietary Habits_Unhealthy                             False
# Air Pollution Exposure_Low                           False
# Air Pollution Exposure_Medium                        False
# Employment Status_Retired                            False
# Employment Status_Unemployed                         False
# Marital Status_Single                                False
# Marital Status_Widowed                               False
# Genetic Risk Factor (APOE-ε4 allele)_Yes             False
# Social Engagement Level_Low                          False
# Social Engagement Level_Medium                       False
# Income Level_Low                                      True
# Income Level_Medium                                   True
# Stress Levels_Low                                    False
# Stress Levels_Medium                                 False
# Urban vs Rural Living_Urban                          False
# Alzheimer’s Diagnosis_Yes                            False
#
#                                           Income Level_Medium  \
# Age                                                     False
# Education Level                                         False
# BMI                                                     False
# Cognitive Test Score                                    False
# Gender_Male                                             False
# Physical Activity Level_Low                             False
# Physical Activity Level_Medium                          False
# Smoking Status_Former                                   False
# Smoking Status_Never                                    False
# Alcohol Consumption_Occasionally                        False
# Alcohol Consumption_Regularly                           False
# Diabetes_Yes                                            False
# Hypertension_Yes                                        False
# Cholesterol Level_Normal                                False
# Family History of Alzheimer’s_Yes                       False
# Depression Level_Low                                    False
# Depression Level_Medium                                 False
# Sleep Quality_Good                                      False
# Sleep Quality_Poor                                      False
# Dietary Habits_Healthy                                  False
# Dietary Habits_Unhealthy                                False
# Air Pollution Exposure_Low                              False
# Air Pollution Exposure_Medium                           False
# Employment Status_Retired                               False
# Employment Status_Unemployed                            False
# Marital Status_Single                                   False
# Marital Status_Widowed                                  False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                False
# Social Engagement Level_Low                             False
# Social Engagement Level_Medium                          False
# Income Level_Low                                         True
# Income Level_Medium                                      True
# Stress Levels_Low                                       False
# Stress Levels_Medium                                    False
# Urban vs Rural Living_Urban                             False
# Alzheimer’s Diagnosis_Yes                               False
#
#                                           Stress Levels_Low  \
# Age                                                   False
# Education Level                                       False
# BMI                                                   False
# Cognitive Test Score                                  False
# Gender_Male                                           False
# Physical Activity Level_Low                           False
# Physical Activity Level_Medium                        False
# Smoking Status_Former                                 False
# Smoking Status_Never                                  False
# Alcohol Consumption_Occasionally                      False
# Alcohol Consumption_Regularly                         False
# Diabetes_Yes                                          False
# Hypertension_Yes                                      False
# Cholesterol Level_Normal                              False
# Family History of Alzheimer’s_Yes                     False
# Depression Level_Low                                  False
# Depression Level_Medium                               False
# Sleep Quality_Good                                    False
# Sleep Quality_Poor                                    False
# Dietary Habits_Healthy                                False
# Dietary Habits_Unhealthy                              False
# Air Pollution Exposure_Low                            False
# Air Pollution Exposure_Medium                         False
# Employment Status_Retired                             False
# Employment Status_Unemployed                          False
# Marital Status_Single                                 False
# Marital Status_Widowed                                False
# Genetic Risk Factor (APOE-ε4 allele)_Yes              False
# Social Engagement Level_Low                           False
# Social Engagement Level_Medium                        False
# Income Level_Low                                      False
# Income Level_Medium                                   False
# Stress Levels_Low                                      True
# Stress Levels_Medium                                   True
# Urban vs Rural Living_Urban                           False
# Alzheimer’s Diagnosis_Yes                             False
#
#                                           Stress Levels_Medium  \
# Age                                                      False
# Education Level                                          False
# BMI                                                      False
# Cognitive Test Score                                     False
# Gender_Male                                              False
# Physical Activity Level_Low                              False
# Physical Activity Level_Medium                           False
# Smoking Status_Former                                    False
# Smoking Status_Never                                     False
# Alcohol Consumption_Occasionally                         False
# Alcohol Consumption_Regularly                            False
# Diabetes_Yes                                             False
# Hypertension_Yes                                         False
# Cholesterol Level_Normal                                 False
# Family History of Alzheimer’s_Yes                        False
# Depression Level_Low                                     False
# Depression Level_Medium                                  False
# Sleep Quality_Good                                       False
# Sleep Quality_Poor                                       False
# Dietary Habits_Healthy                                   False
# Dietary Habits_Unhealthy                                 False
# Air Pollution Exposure_Low                               False
# Air Pollution Exposure_Medium                            False
# Employment Status_Retired                                False
# Employment Status_Unemployed                             False
# Marital Status_Single                                    False
# Marital Status_Widowed                                   False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                 False
# Social Engagement Level_Low                              False
# Social Engagement Level_Medium                           False
# Income Level_Low                                         False
# Income Level_Medium                                      False
# Stress Levels_Low                                         True
# Stress Levels_Medium                                      True
# Urban vs Rural Living_Urban                              False
# Alzheimer’s Diagnosis_Yes                                False
#
#                                           Urban vs Rural Living_Urban  \
# Age                                                             False
# Education Level                                                 False
# BMI                                                             False
# Cognitive Test Score                                            False
# Gender_Male                                                     False
# Physical Activity Level_Low                                     False
# Physical Activity Level_Medium                                  False
# Smoking Status_Former                                           False
# Smoking Status_Never                                            False
# Alcohol Consumption_Occasionally                                False
# Alcohol Consumption_Regularly                                   False
# Diabetes_Yes                                                    False
# Hypertension_Yes                                                False
# Cholesterol Level_Normal                                        False
# Family History of Alzheimer’s_Yes                               False
# Depression Level_Low                                            False
# Depression Level_Medium                                         False
# Sleep Quality_Good                                              False
# Sleep Quality_Poor                                              False
# Dietary Habits_Healthy                                          False
# Dietary Habits_Unhealthy                                        False
# Air Pollution Exposure_Low                                      False
# Air Pollution Exposure_Medium                                   False
# Employment Status_Retired                                       False
# Employment Status_Unemployed                                    False
# Marital Status_Single                                           False
# Marital Status_Widowed                                          False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                        False
# Social Engagement Level_Low                                     False
# Social Engagement Level_Medium                                  False
# Income Level_Low                                                False
# Income Level_Medium                                             False
# Stress Levels_Low                                               False
# Stress Levels_Medium                                            False
# Urban vs Rural Living_Urban                                      True
# Alzheimer’s Diagnosis_Yes                                       False
#
#                                           Alzheimer’s Diagnosis_Yes
# Age                                                            True
# Education Level                                               False
# BMI                                                           False
# Cognitive Test Score                                          False
# Gender_Male                                                   False
# Physical Activity Level_Low                                   False
# Physical Activity Level_Medium                                False
# Smoking Status_Former                                         False
# Smoking Status_Never                                          False
# Alcohol Consumption_Occasionally                              False
# Alcohol Consumption_Regularly                                 False
# Diabetes_Yes                                                  False
# Hypertension_Yes                                              False
# Cholesterol Level_Normal                                      False
# Family History of Alzheimer’s_Yes                             False
# Depression Level_Low                                          False
# Depression Level_Medium                                       False
# Sleep Quality_Good                                            False
# Sleep Quality_Poor                                            False
# Dietary Habits_Healthy                                        False
# Dietary Habits_Unhealthy                                      False
# Air Pollution Exposure_Low                                    False
# Air Pollution Exposure_Medium                                 False
# Employment Status_Retired                                     False
# Employment Status_Unemployed                                  False
# Marital Status_Single                                         False
# Marital Status_Widowed                                        False
# Genetic Risk Factor (APOE-ε4 allele)_Yes                      False
# Social Engagement Level_Low                                   False
# Social Engagement Level_Medium                                False
# Income Level_Low                                              False
# Income Level_Medium                                           False
# Stress Levels_Low                                             False
# Stress Levels_Medium                                          False
# Urban vs Rural Living_Urban                                   False
# Alzheimer’s Diagnosis_Yes                                      True
#
# [36 rows x 36 columns]

# %% [markdown]
# There is some correlation between features, but it is usually between features like Physical Activity_Low and Physical Activity_Medium. I do not think it is worth removing these features as it could negatively impact the result. The correlation between these features is greater than -0.4 (close to 0). There are no other features correlated closely.
